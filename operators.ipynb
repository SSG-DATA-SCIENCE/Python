# %%
#operator>>special keywords to perform operations.. to manipulate data

# %%
#airthmetic Operators +,-,*,/,%,**,//

# %%
a=5
b=3

# %%
a+b
# Out:
# 8

# %%
a-b
# Out:
# 2

# %%
a*b
# Out:
# 15

# %%
a/b
# Out:
# 1.6666666666666667

# %%
a**b  #5^3
# Out:
# 125

# %%
a%b #giving remainder when we divide a/b
# Out:
# 2

# %%
a//b #floor function giving the value of integer extracting decimal part(1.6666)
# Out:
# 1

# %%
#Comparision Operator.. ==, != , > , < , >= , <= ..... compare and give boolean(true or false) value

# %%
2==2
# Out:
# True

# %%
2==7
# Out:
# False

# %%
2!=7
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
10>2
# Out:
# True

# %%
2>10
# Out:
# False

# %%
10<2
# Out:
# False

# %%
2<10
# Out:
# True

# %%
9>=9
# Out:
# True

# %%
9>=10
# Out:
# False

# %%
8<=2
# Out:
# False

# %%
9<=9
# Out:
# True

# %%
#Logical Operator>> AND , OR, NOT
#Condition1 Condition2   AND     OR         condition1     NOT
#TRUE         True      TRUE    TRUE            True      FALSE
#True         False     False   True            False     True
#False        True      False   True
#False        False     False   False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
#Assignment Operator =,+=,-=,*=,/=

# %%
a=10

# %%
a+=5 #a=a+5
a
# Out:
# 15

# %%
a-=5 #a=a-5
a
# Out:
# 10

# %%
a*=7 #a=a*7
a
# Out:
# 70

# %%
a/=10 #a=a/10
a
# Out:
# 7.0

# %%
#Membership Operator in,not in

# %%
a="SSG"
"S" in a
# Out:
# True

# %%
a="SSG"
"S" not in a
# Out:
# False

# %%
"am" in "I am SSG "
# Out:
# True

# %%
a=["SSG","Data","Science"]
"Data" in a
# Out:
# True

# %%
"Data1" in a
# Out:
# False

# %%
#Identify Operator ---- compare memory loacations of two objects

# %%
a=5
b=7
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a="SSG"
b=a
a is b
# Out:
# True

# %%
#Bitwise Operator >> Bitwise AND ,Bitwise OR , Bitwise NOT , BITWISE XOR , LEFT SHIFT(<<) , RIGHT SHIFT(>>)
#operation between bits

# %%
bin(18) #bin-Binary
# Out:
# '0b10010'

# %%
bin(2)
# Out:
# '0b10'

# %%
18&2 #bitwise AND
# Out:
# 2

# %%
18|2  #bitwise OR
# Out:
# 18

# %%
~2  # Bitwise NOT
# Out:
# -3

# %%
18^2 #Bitwise Xor
# Out:
# 16

# %%
18<<2   # left shift
# Out:
# 72

# %%
18>>2  # Right Shift
# Out:
# 4
