# %%
Name=input("please Enter your name:")
# Out:
# please Enter your name:1

# %%
int(Name)
# Out:
# 1

# %%
s="12"
type(s)
# Out:
# str

# %%
int(s)
# Out:
# 12

# %%
s="1.12121"
type(s)
# Out:
# str

# %%
float(s)
# Out:
# 1.12121

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True
